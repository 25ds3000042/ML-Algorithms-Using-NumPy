# %% [markdown]
# <a href="https://colab.research.google.com/github/25ds3000042/ML-Algorithms-Using-NumPy/blob/main/T2_2026_MLT_Workshop_Assignment_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLT Workshop Assignment For Day 1
#
# **Topics covered:** Vectors in NumPy · Plotting simple curves · Matrices in NumPy
#
# ### Instructions
# - Go to **File → Save a copy in Drive** before you begin, so you can edit your own copy.
# - Run the import cell first. Each question has a code cell below it; some already contain the given data, so you don't have to retype it.
# - Where a ** Check** is given, use it to verify your answer. Try to predict the output *before* running your code.
# - Use NumPy operations (not loops) unless the question says otherwise.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Part A: Vectors

# %% [markdown]
# ### Q1. Lists vs NumPy arrays
# Let `a = [2, 4, 6]` and `b = [1, 3, 5]`.
#
# 1. *Before running*, write down what you expect `a + b` and `2 * a` to give for **Python lists**. Then run them.
# 2. Convert both to NumPy arrays and compute `a + b` and `2 * a` again.
# 3. In the markdown cell below, explain in one or two lines why the results differ.

# %%
a = [2, 4, 6]
b = [1, 3, 5]

# Write your code here

# %% [markdown]
# *Your explanation:*

# %% [markdown]
# ### Q2. Temperature conversion (element-wise function)
# The maximum daily temperatures (°C) for a week are:
#
# $$\mathbf{c} = [28.5,\ 31.2,\ 33.0,\ 29.8,\ 35.1,\ 36.4,\ 30.0]$$
#
# Convert every value to Fahrenheit using $f(c) = \frac{9}{5}c + 32$ in a single line, and round the result to 1 decimal place (`np.round`).
#
# **Check:** the first two values should be `83.3` and `88.2`.

# %%
c = np.array([28.5, 31.2, 33.0, 29.8, 35.1, 36.4, 30.0])

# Write your code here

# %% [markdown]
# ### Q3. Grocery bill: Hadamard product vs dot product
# Prices of 4 items (₹): $\mathbf{p} = [40, 25, 120, 60]$, quantities bought: $\mathbf{q} = [3, 10, 1, 2]$.
#
# 1. Compute the cost for each item using the **element-wise (Hadamard) product** $\mathbf{p} \odot \mathbf{q}$.
# 2. Compute the total bill using the **dot product** $\mathbf{p}^T\mathbf{q}$ with the `@` operator.
# 3. Verify that `np.sum` of part 1 equals your answer to part 2.
#
# **Check:** total bill = ₹610.

# %%
p = np.array([40, 25, 120, 60])
q = np.array([3, 10, 1, 2])

# Write your code here

# %% [markdown]
# ### Q4. Logs and exponentials element-wise
# Let $\mathbf{x} = [1, 2, 4, 8, 16, 32, 64]$.
#
# 1. Apply $\log_2(x)$ element-wise. What pattern do you see?
# 2. Apply $\sqrt{x}$ element-wise.
# 3. Apply $\ln(x)$ and then $e^{(\cdot)}$ to the result. Use `np.allclose` to confirm that you get back the original $\mathbf{x}$.

# %%
# Write your code here

# %% [markdown]
# ### Q5. Creating vectors without typing every element
# Using `np.ones`, `np.zeros`, `np.arange` and element-wise operations (no manual listing of values), create:
#
# 1. A vector of length 7 in which every element is $-2.5$.
# 2. All even numbers from 10 to 30 (both inclusive).
# 3. The vector of squares $[1, 4, 9, 16, \dots, 100]$.
# 4. The vector $[10, 7, 4, 1, -2]$ (hint: `np.arange` can take a negative step).

# %%
# Write your code here

# %% [markdown]
# ### Q6. Norms and unit vectors
# Let $\mathbf{x} = [3, -4, 12]$.
#
# 1. Compute $\|\mathbf{x}\|_2$ and $\|\mathbf{x}\|_1$ **from the formula** (using `np.sqrt`, `np.abs`, `np.sum`).
# 2. Compute the same using `np.linalg.norm` (use the `ord` argument for L1).
# 3. Compute the $L_\infty$ norm (`ord = np.inf`). What does it represent?
# 4. Find the unit vector $\hat{\mathbf{x}} = \mathbf{x} / \|\mathbf{x}\|_2$ and verify that its L2 norm is 1.
#
#  **Check:** $\|\mathbf{x}\|_2 = 13$, $\|\mathbf{x}\|_1 = 19$.

# %%
# Write your code here

# %% [markdown]
# ### Q7. Distance between two data points
# In ML (for example, in k-Nearest Neighbours) we often measure how far apart two data points are. For
#
# $$\mathbf{p} = [1, 2, 3], \quad \mathbf{q} = [4, 6, 15]$$
#
# compute the **Euclidean distance** $\|\mathbf{p} - \mathbf{q}\|_2$ and the **Manhattan distance** $\|\mathbf{p} - \mathbf{q}\|_1$.
#
# Do you notice any connection with Q6?

# %%
# Write your code here

# %% [markdown]
# ### Q8. Angle between vectors
# The angle $\theta$ between two vectors satisfies
# $$\cos\theta = \frac{\mathbf{u}^T\mathbf{v}}{\|\mathbf{u}\|_2\,\|\mathbf{v}\|_2}$$
#
# 1. For $\mathbf{u} = [1, 2, 2]$ and $\mathbf{v} = [2, 1, -2]$, compute $\cos\theta$. What can you say about these two vectors?
# 2. For $\mathbf{w} = [1, 1, 0]$ and $\mathbf{z} = [1, 0, 0]$, compute $\theta$ in degrees (use `np.arccos` and `np.degrees`).
#
#  **Check:** part 2 gives 45°.

# %%
# Write your code here

# %% [markdown]
# ### Q9. Predict `ndim` and `shape`
# For each array below, first **predict** `ndim` and `shape` and fill in the table, then run the code to verify.
#
# | Array | Predicted `ndim` | Predicted `shape` | Actual |
# |---|---|---|---|
# | `np.array([5])` | | | |
# | `np.array([[5]])` | | | |
# | `np.array([[1, 2], [3, 4], [5, 6]])` | | | |
# | `np.zeros((2, 3, 4))` | | | |
# | `np.array([[[1], [2]]])` | | | |
#
# Which two arrays hold the same single number but have different `ndim`?

# %%
arrays = [np.array([5]),
          np.array([[5]]),
          np.array([[1, 2], [3, 4], [5, 6]]),
          np.zeros((2, 3, 4)),
          np.array([[[1], [2]]])]

# Write your code here (print ndim and shape of each)

# %% [markdown]
# ---
# ## Part B: Plotting Simple Curves

# %% [markdown]
# ### Q10. Two lines and their intersection
# Plot $y = 2x + 1$ and $y = -x + 4$ on the **same** plot for $x \in [-2, 4]$ using 25 equally spaced points.
#
# - Use different colours and add a legend.
# - Find the point of intersection by hand, then mark it on the plot using `plt.scatter`.
# - Label both axes, add a title, and turn on the grid (`plt.grid()`).
#
#  **Check:** the lines meet at $(1, 3)$.

# %%
# Write your code here

# %% [markdown]
# ### Q11. How many points are enough?
# Plot $y = \sin(3x)$ for $x \in [0, 2\pi]$ using **6**, **15** and **100** equally spaced points, as three side-by-side subplots (1 row, 3 columns). Put the number of points in each subplot's title.
#
# Which plot represents the curve faithfully? Why does the 6-point plot look so misleading?

# %%
# Write your code here

# %% [markdown]
# ### Q12. The sigmoid function
# The sigmoid function is used heavily in ML (for example, in logistic regression):
# $$\sigma(x) = \frac{1}{1 + e^{-x}}$$
#
# 1. Plot $\sigma(x)$ for $x \in [-8, 8]$ with 200 points.
# 2. On the same plot, draw its derivative $\sigma(x)\,(1 - \sigma(x))$ in a different colour.
# 3. Add a dashed horizontal line at $y = 0.5$ and a dashed vertical line at $x = 0$ (`linestyle='--'`).
# 4. Add a legend, axis labels and a title.
#
# At what value of $x$ is the derivative largest?

# %%
# Write your code here

# %% [markdown]
# ### Q13. A 2 × 2 grid of subplots
# Plot each of the following in its own subplot, in a 2 × 2 grid, with the equation as the subplot title:
#
# - $y = x^3, \quad x \in [-2, 2]$
# - $y = |x|, \quad x \in [-3, 3]$
# - $y = e^{-x^2}, \quad x \in [-3, 3]$ (the bell curve shape)
# - $y = \ln(1 + x), \quad x \in [0, 10]$
#
# Use `plt.tight_layout()` so that the titles don't overlap.

# %%
# Write your code here

# %% [markdown]
# ### Q14. A family of curves using a loop
# Using a `for` loop, plot $y = x^n$ for $n = 1, 2, 3, 4, 5$ on the same plot, for $x \in [0, 1]$. Each curve should get a legend entry such as `n = 3`.
#
# What happens to $x^n$ on $[0, 1]$ as $n$ increases? Which point do all curves pass through?

# %%
# Write your code here

# %% [markdown]
# ---
# ## Part C: Matrices

# %% [markdown]
# ### Q15. Building a matrix with `arange` and `reshape`
# 1. Create the $3 \times 4$ matrix $\mathbf{M}$ with entries $1, 2, \dots, 12$ filled row by row, using `np.arange` and `reshape`.
# 2. Print its `ndim`, `shape` and `size`.
# 3. Find $\mathbf{M}^T$ and its shape.
# 4. Verify that $(\mathbf{M}^T)^T = \mathbf{M}$ using `np.array_equal`.
# 5. What happens if you try `np.arange(1, 13).reshape(5, 3)`? Why?

# %%
# Write your code here

# %% [markdown]
# ### Q16. Matrix arithmetic and products
# $$\mathbf{A} = \begin{bmatrix} 2 & -1 \\ 0 & 3 \end{bmatrix}, \quad \mathbf{B} = \begin{bmatrix} 1 & 4 \\ -2 & 5 \end{bmatrix}$$
#
# Compute:
# 1. $\mathbf{A} + \mathbf{B}$ and $2\mathbf{A} - 3\mathbf{B}$
# 2. $\mathbf{A} \odot \mathbf{B}$ (element-wise) and $\mathbf{AB}$ (matrix product). Are they the same?
# 3. $\mathbf{AB}$ and $\mathbf{BA}$. Is matrix multiplication commutative?
# 4. Verify that $(\mathbf{AB})^T = \mathbf{B}^T\mathbf{A}^T$.
#
#  **Check:** $\mathbf{AB} = \begin{bmatrix} 4 & 3 \\ -6 & 15 \end{bmatrix}$

# %%
A = np.array([[2, -1], [0, 3]])
B = np.array([[1, 4], [-2, 5]])

# Write your code here

# %% [markdown]
# ### Q17. Row vectors, column vectors, inner and outer products
# Start with the 1-D array `x = np.array([2, 5, 7])`.
#
# 1. Convert it into a **row vector** of shape `(1, 3)` and a **column vector** of shape `(3, 1)`, once using `reshape` and once using `np.newaxis`.
# 2. Compute `row @ col`. What is its shape? Compare it with the plain dot product `x @ x`.
# 3. Compute `col @ row`. What is its shape? Compare it with `np.outer(x, x)`.
# 4. What happens if you try `row @ row`? Explain the error.

# %%
x = np.array([2, 5, 7])

# Write your code here

# %% [markdown]
# ### Q18. A small data matrix
# The marks of 5 students in 3 subjects are stored in a data matrix $\mathbf{X}$ (rows = students, columns = subjects). The subjects carry weights $\mathbf{w} = [0.3, 0.3, 0.4]$.
#
# 1. Compute every student's weighted score with **one** matrix–vector product $\mathbf{Xw}$.
# 2. Which student has the highest weighted score? (Hint: `np.argmax`.)
# 3. Compute the average marks per subject as $\frac{1}{n}\mathbf{1}^T\mathbf{X}$, where $\mathbf{1}$ is a vector of ones of length $n = 5$. Verify it with `X.mean(axis=0)`.
#
# **Check:** weighted scores are `[85.7, 63.4, 91.4, 63.1, 83.5]`.

# %%
X = np.array([[78, 85, 92],
              [64, 70, 58],
              [90, 88, 95],
              [55, 62, 70],
              [82, 79, 88]])
w = np.array([0.3, 0.3, 0.4])

# Write your code here

# %% [markdown]
# ### Q19. Special matrices
# 1. Create a $4 \times 4$ identity matrix, a $2 \times 5$ matrix of zeros and a $3 \times 2$ matrix of ones.
# 2. Create the diagonal matrix $\mathbf{D}$ with diagonal $\mathbf{d} = [5, -1, 2]$ using `np.diag`.
# 3. For $\mathbf{v} = [1, 2, 3]$, verify that $\mathbf{Dv}$ gives the same result as the element-wise product $\mathbf{d} \odot \mathbf{v}$. Why does this happen?
# 4. Build the matrix $\mathbf{M} = 2\mathbf{I}_3 + \mathbf{J}_3$, where $\mathbf{J}_3$ is the $3 \times 3$ matrix of ones. What does it look like?
# 5. What does `np.diag` return when you pass it a **matrix** instead of a vector? Try it on $\mathbf{M}$.

# %%
# Write your code here

# %% [markdown]
# ### Q20. Indexing and slicing
# Let `M = np.arange(1, 26).reshape(5, 5)`. Using indexing and slicing only, extract:
#
# 1. The element $13$
# 2. The 4th row
# 3. The last column (use a negative index)
# 4. The central $3 \times 3$ submatrix
# 5. The four corner elements as a $2 \times 2$ matrix (hint: use a step, `::4`)
# 6. Every alternate row, starting from the first
# 7. The matrix with its rows in reverse order
#
# Finally, make a **copy** of `M` and set its entire 2nd column to 0. Print both to confirm that the original `M` is unchanged.

# %%
M = np.arange(1, 26).reshape(5, 5)
print(M)

# Write your code here

# %% [markdown]
# ### Q21. Rank, inverse and pseudoinverse
# $$\mathbf{A} = \begin{bmatrix} 2 & 1 \\ 5 & 3 \end{bmatrix}, \quad \mathbf{B} = \begin{bmatrix} 1 & 2 \\ 2 & 4 \end{bmatrix}$$
#
# 1. Find the rank of $\mathbf{A}$ and $\mathbf{B}$ using `np.linalg.matrix_rank`.
# 2. Compute $\mathbf{A}^{-1}$ and verify that $\mathbf{AA}^{-1} = \mathbf{I}$ using `np.allclose`.
# 3. Use $\mathbf{A}^{-1}$ to solve the system: $\ 2x + y = 5,\quad 5x + 3y = 13$.
# 4. Try `np.linalg.inv(B)`. What happens and why?
# 5. Compute the pseudoinverse $\mathbf{B}^{\dagger}$ using `np.linalg.pinv` and verify that $\mathbf{B}\mathbf{B}^{\dagger}\mathbf{B} = \mathbf{B}$.
# 6. What is the rank of the outer product matrix you built in Q17? Can you guess the rank of *any* outer product $\mathbf{x}\mathbf{y}^T$ (with non-zero vectors)?
#
#  **Check:** the solution in part 3 is $x = 2, y = 1$.

# %%
A = np.array([[2, 1], [5, 3]])
B = np.array([[1, 2], [2, 4]])

# Write your code here

# %% [markdown]
# ### Q22. Eigenvalues and eigenvectors
# $$\mathbf{S} = \begin{bmatrix} 4 & 1 \\ 1 & 4 \end{bmatrix}$$
#
# 1. Compute the eigenvalues and eigenvectors of $\mathbf{S}$ using `np.linalg.eigh` (meant for symmetric matrices).
# 2. For **each** eigenpair $(\lambda_i, \mathbf{v}_i)$, verify that $\mathbf{S}\mathbf{v}_i = \lambda_i\mathbf{v}_i$. (Remember: eigenvectors are the **columns** of the returned matrix; use slicing.)
# 3. Let $\mathbf{V}$ be the matrix of eigenvectors. Verify that $\mathbf{V}^T\mathbf{V} = \mathbf{I}$. What does this say about the eigenvectors?
# 4. Reconstruct $\mathbf{S}$ as $\mathbf{V}\boldsymbol{\Lambda}\mathbf{V}^T$, where $\boldsymbol{\Lambda}$ = `np.diag(eigenvalues)`.
# 5. Compare the sum of the eigenvalues with the sum of the diagonal of $\mathbf{S}$ (`np.trace`). What do you notice?
#
#  **Check:** the eigenvalues are 3 and 5.

# %%
S = np.array([[4, 1], [1, 4]])

# Write your code here

# %% [markdown]
# ---
# ### End of Assignment
# If you finish early, try changing the numbers in any question and predict the new output before running it.
