# %% [markdown]
# <a href="https://colab.research.google.com/github/25ds3000042/ML-Algorithms-Using-NumPy/blob/main/ML_NumPy_Workshop_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# linspace is a NumPy function used to create numbers that are evenly spaced between a starting value and an ending value.

# %%
x = np.linspace(0, 10, 5)
print(x)
# Out:
# [ 0.   2.5  5.   7.5 10. ]
